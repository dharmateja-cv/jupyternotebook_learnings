# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv(r'E:\Jupyter Notebook Learnings\data_1.csv')

df.head()
# Out:
#           Date      Open      High       Low     Close  Shares Traded  \
# 0  01-Jun-2020   9726.85   9931.60   9706.95   9826.15      794183122
# 1  02-Jun-2020   9880.85   9995.60   9824.05   9979.10      770192848
# 2  03-Jun-2020  10108.30  10176.20  10035.55  10061.55      794664422
# 3  04-Jun-2020  10054.25  10123.85   9944.25  10029.10      775106567
# 4  05-Jun-2020  10093.80  10177.80  10040.75  10142.15      987122302
#
#    Turnover (Rs. Cr)
# 0           38096.92
# 1           36723.11
# 2           38343.61
# 3           36399.04
# 4           37824.63

# %% [markdown]
# plt.title("my Learning")
#
#
# plt.xticks(
#     rotation=90,
#     horizontalalignment='right',
#     fontweight='light',
#     fontsize='x-large',
#
#
# )
#
# plt.bar(x=df['Date'],width = 0.5,height=df['Open'])
#
# plt.rcParams["figure.figsize"] = [16,9]

# %%
df.plot(x="Date", y=["Open", "Close"], kind="bar")

# %%
ax = df.plot(x="Date", y="Open", kind="bar")
df.plot(x="Date", y="Close", kind="bar", ax=ax, color="C2")
##df.plot(x="Date", y="High", kind="bar", ax=ax, color="C3")

# %%
df.plot(x="Date", y=["Open","Close"], kind="area")

# %%
df.plot(x="Date", y=["Open", "Close","Low","High"], kind="bar",stacked=False)

# %%
plt.figure();

# %%
np.array([(1,2,3,4),(5,5,6,6,78)])
# Out:
# array([(1, 2, 3, 4), (5, 5, 6, 6, 78)], dtype=object)

# %%
np.array([(1,2,3,4),(5,5,6,6,78)]).shape
# Out:
# (2,)

# %%
b=np.array([(1,2,3,4),(5,5,6,6,78),(12,13,19)])

# %%
b
b.size
b.shape
# Out:
# (3,)

# %%
c=np.split(b,[1])

# %%
c
# Out:
# [array([(1, 2, 3, 4)], dtype=object),
#  array([(5, 5, 6, 6, 78), (12, 13, 19)], dtype=object)]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-b487cbcb8b7e> in <module>
# ----> 1 c.size
#
# AttributeError: 'list' object has no attribute 'size'
